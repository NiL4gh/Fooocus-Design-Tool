# %% [markdown]
# # 🎨 Fooocus Design Tool
# **AI-Powered Graphic Design Asset Generator**
#
# Built on Z-Image-Turbo for fast, high-quality design asset generation.
#
# ### Features:
# - 🎯 Design categories (Logo, Poster, Banner, and more)
# - 🏷️ **Adobe Stock Tuning** (Silhouettes & Flat Vectors presets)
# - 🧠 Auto prompt enhancement & Custom color palette control
# - 🔲 Transparent PNG background removal (via rembg)
# - ✏️ Vector mode (lossless SVG conversion via StarVector-1B)
# - 🔄 Multi-seed variation generator
# - 📦 **Premium Mockup Generator** (Single Centered, Bento Knolling, and Ambient Scenes)
# - 🔲 **Flexible Layouts** (Toggleable 2x2 Concept Grid on the main panel)
# - 🧹 **VRAM Cleanup Utility** (Instant GPU memory purge button to prevent Colab OOMs)
#
# ---
# **Runtime:** Make sure GPU is enabled: `Runtime → Change runtime type → T4 GPU`

# %%
# Cell 1: Clone and Install
# !git clone https://github.com/NiL4gh/Fooocus-Design-Tool.git
# %cd Fooocus-Design-Tool
# !pip install -r requirements.txt -q
print('📥 Pre-downloading models (caching weights for instant UI startup)...')
# !python -c "import os; os.environ['MOCK_IMAGE_GEN'] = '0'; from modules.zimage_pipeline import load_pipeline, unload_pipeline; load_pipeline(model_name='FLUX.1-schnell'); unload_pipeline(); from modules.starvector_pipeline import load_model, unload_model; load_model(); unload_model()"
print('✅ Installation and model download complete!')

# %%
# Cell 2 (OPTIONAL): Setup ngrok for a stable public URL
# Uncomment and add your ngrok token:
# !pip install pyngrok -q
# from pyngrok import ngrok
# ngrok.set_auth_token('YOUR_NGROK_TOKEN')
# tunnel = ngrok.connect(7865)
# print(f'Public URL: {tunnel.public_url}')

# %%
# Cell 3: Launch the Design Tool
# !python launch.py --share
